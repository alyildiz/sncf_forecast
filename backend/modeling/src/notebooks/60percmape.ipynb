# %%
from src.extract_data import load_data, process_data
from src.utils import get_test_set
import pandas as pd
from src.constants import FILE_PATH
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
import numpy as np 
import seaborn as sns
set_matplotlib_formats('svg')
import tensorflow as tf
import IPython
import IPython.display

from src.utils import build_time_series

# %%
def plot_test(x_test, y_test, model = None):
    y_test = y_test.reshape(y_test.shape[0], -1)
    fix, ax = plt.subplots(y_test.shape[1] , 1, figsize=(10,7))
    
    if y_test.shape[1] == 1:
        historical_index = [x for x in range(x_test.shape[0])]
        pred_index = [x+x_test.shape[0] for x in range(y_test.shape[0])]

        ax.plot(historical_index, x_test[:, 0], marker='.', label='Input')
        ax.scatter(pred_index, y_test[:, 0], edgecolors='k', label='Labels', c='#2ca02c', s=32)

        if model is not None:
            preds = model(np.expand_dims(x_test, axis=0))[0]
            ax.scatter(pred_index, preds[:, 0],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)
            
    else:
        for i in range(y_test.shape[1]):
            historical_index = [x for x in range(x_test.shape[0])]
            pred_index = [x+x_test.shape[0] for x in range(y_test.shape[0])]

            ax[i].plot(historical_index, x_test[:, i], marker='.', label='Input')
            ax[i].scatter(pred_index, y_test[:, i], edgecolors='k', label='Labels', c='#2ca02c', s=32)

            if model is not None:
                preds = model(np.expand_dims(x_test, axis=0))[0]
                ax[i].scatter(pred_index, preds[:, i],
                      marker='X', edgecolors='k', label='Predictions',
                      c='#ff7f0e', s=64)
    
    plt.legend()

# %%
FORECAST_SIZE = 5
WINDOW_SIZE = FORECAST_SIZE * 10
NUM_FEATURES = 1

# %%
df = load_data(FILE_PATH)
df = process_data(df, use_covariates=False)

# %%
#df = df.drop(['day_of_month', 'month'], axis=1)
df.head()
# Out:
#             nbr_travels  nbr_late_trains
# date
# 2019-03-01        18680             1799
# 2019-03-02        12341             1049
# 2019-03-03        10839              969
# 2019-03-04        18502             2228
# 2019-03-05        18373             1767

# %%
n = len(df)
train_df = df[0:int(n*0.7)].astype(float)
val_df = df[int(n*0.7):int(n*0.9)].astype(float)
test_df = df[int(n*0.9):].astype(float)

# %%
def normalize(data):
    dic = {}
    for col in ['nbr_travels', 'nbr_late_trains']:
        data_mean = data[col].mean()
        data_std = data[col].std()
        dic[col] = [data_mean, data_std]
    return dic

dic = normalize(train_df)

# %%
train_df['nbr_travels'] = (train_df['nbr_travels'] - dic['nbr_travels'][0]) / dic['nbr_travels'][1]
train_df['nbr_late_trains'] = (train_df['nbr_late_trains'] - dic['nbr_late_trains'][0]) / dic['nbr_late_trains'][1]

val_df['nbr_travels'] = (val_df['nbr_travels'] - dic['nbr_travels'][0]) / dic['nbr_travels'][1]
val_df['nbr_late_trains'] = (val_df['nbr_late_trains'] - dic['nbr_late_trains'][0]) / dic['nbr_late_trains'][1]

test_df['nbr_travels'] = (test_df['nbr_travels'] - dic['nbr_travels'][0]) / dic['nbr_travels'][1]
test_df['nbr_late_trains'] = (test_df['nbr_late_trains'] - dic['nbr_late_trains'][0]) / dic['nbr_late_trains'][1]

# %%
#train_df = train_df.drop('nbr_late_trains', axis=1)
#val_df = val_df.drop('nbr_late_trains', axis=1)
#test_df = test_df.drop('nbr_late_trains', axis=1)


train_df.head()
# Out:
#             nbr_travels  nbr_late_trains
# date
# 2019-03-01     1.256222         0.793774
# 2019-03-02    -0.239490        -0.356145
# 2019-03-03    -0.593893        -0.478803
# 2019-03-04     1.214223         1.451528
# 2019-03-05     1.183785         0.744711

# %%
train_x, train_y = build_time_series(train_df, window_size=WINDOW_SIZE, forecast_size=FORECAST_SIZE)
val_x, val_y = build_time_series(val_df, window_size=WINDOW_SIZE, forecast_size=FORECAST_SIZE)
test_x, test_y = build_time_series(test_df, window_size=WINDOW_SIZE, forecast_size=FORECAST_SIZE)

train_y = train_y[:, :, 0]
val_y = val_y[:, :, 0]
test_y = test_y[:, :, 0]

# %%
plot_test(test_x[0], test_y[0])

# %%
def compile_and_fit(model, max_epochs, train_x, train_y, val_x, val_y, patience=20):
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')
    model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(),
                metrics=[tf.metrics.MeanAbsoluteError()])
    
    history = model.fit(train_x, train_y, epochs=max_epochs,
                      validation_data=(val_x, val_y),
                      callbacks=[early_stopping])
    return history

# %%
multi_lstm_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, lstm_units].
    # Adding more `lstm_units` just overfits more quickly.
    tf.keras.layers.GRU(64, return_sequences=False),

    tf.keras.layers.Dense(FORECAST_SIZE*NUM_FEATURES),
    # Shape => [batch, out_steps, features].
    tf.keras.layers.Reshape([FORECAST_SIZE, NUM_FEATURES])
])

history = compile_and_fit(
    multi_lstm_model,
    500,
    train_x,
    train_y,
    val_x,
    val_y)

#IPython.display.clear_output()
# Out:
# Epoch 1/500
# 19/19 [==============================] - 2s 43ms/step - loss: 0.7320 - mean_absolute_error: 0.7676 - val_loss: 0.5931 - val_mean_absolute_error: 0.7236
# Epoch 2/500
# 19/19 [==============================] - 0s 24ms/step - loss: 0.5557 - mean_absolute_error: 0.6459 - val_loss: 0.4974 - val_mean_absolute_error: 0.6565
# Epoch 3/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.5114 - mean_absolute_error: 0.6186 - val_loss: 0.4315 - val_mean_absolute_error: 0.6059
# Epoch 4/500
# 19/19 [==============================] - 0s 26ms/step - loss: 0.4722 - mean_absolute_error: 0.5983 - val_loss: 0.3799 - val_mean_absolute_error: 0.5522
# Epoch 5/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.4316 - mean_absolute_error: 0.5608 - val_loss: 0.3343 - val_mean_absolute_error: 0.4911
# Epoch 6/500
# 19/19 [==============================] - 0s 24ms/step - loss: 0.3887 - mean_absolute_error: 0.5201 - val_loss: 0.2978 - val_mean_absolute_error: 0.4425
# Epoch 7/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.3471 - mean_absolute_error: 0.4748 - val_loss: 0.2751 - val_mean_absolute_error: 0.4234
# Epoch 8/500
# 19/19 [==============================] - 0s 23ms/step - loss: 0.3189 - mean_absolute_error: 0.4488 - val_loss: 0.2598 - val_mean_absolute_error: 0.4086
# Epoch 9/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.2943 - mean_absolute_error: 0.4217 - val_loss: 0.2553 - val_mean_absolute_error: 0.4003
# Epoch 10/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.2707 - mean_absolute_error: 0.3957 - val_loss: 0.2408 - val_mean_absolute_error: 0.3861
# Epoch 11/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.2428 - mean_absolute_error: 0.3644 - val_loss: 0.2133 - val_mean_absolute_error: 0.3515
# Epoch 12/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.2127 - mean_absolute_error: 0.3326 - val_loss: 0.1822 - val_mean_absolute_error: 0.3058
# Epoch 13/500
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1863 - mean_absolute_error: 0.2995 - val_loss: 0.1566 - val_mean_absolute_error: 0.2735
# Epoch 14/500
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1681 - mean_absolute_error: 0.2787 - val_loss: 0.1482 - val_mean_absolute_error: 0.2579
# Epoch 15/500
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1527 - mean_absolute_error: 0.2540 - val_loss: 0.1523 - val_mean_absolute_error: 0.2642
# Epoch 16/500
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1455 - mean_absolute_error: 0.2497 - val_loss: 0.1806 - val_mean_absolute_error: 0.2936
# Epoch 17/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1378 - mean_absolute_error: 0.2303 - val_loss: 0.1514 - val_mean_absolute_error: 0.2544
# Epoch 18/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1359 - mean_absolute_error: 0.2257 - val_loss: 0.1400 - val_mean_absolute_error: 0.2477
# Epoch 19/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1308 - mean_absolute_error: 0.2203 - val_loss: 0.1365 - val_mean_absolute_error: 0.2336
# Epoch 20/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1292 - mean_absolute_error: 0.2141 - val_loss: 0.1340 - val_mean_absolute_error: 0.2334
# Epoch 21/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.1273 - mean_absolute_error: 0.2177 - val_loss: 0.1336 - val_mean_absolute_error: 0.2341
# Epoch 22/500
# 19/19 [==============================] - 0s 24ms/step - loss: 0.1249 - mean_absolute_error: 0.2077 - val_loss: 0.1342 - val_mean_absolute_error: 0.2296
# Epoch 23/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1248 - mean_absolute_error: 0.2120 - val_loss: 0.1402 - val_mean_absolute_error: 0.2449
# Epoch 24/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1227 - mean_absolute_error: 0.2058 - val_loss: 0.1361 - val_mean_absolute_error: 0.2439
# Epoch 25/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1220 - mean_absolute_error: 0.2056 - val_loss: 0.1260 - val_mean_absolute_error: 0.2262
# Epoch 26/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.1206 - mean_absolute_error: 0.2063 - val_loss: 0.1409 - val_mean_absolute_error: 0.2428
# Epoch 27/500
# 19/19 [==============================] - 0s 19ms/step - loss: 0.1177 - mean_absolute_error: 0.1987 - val_loss: 0.1329 - val_mean_absolute_error: 0.2360
# Epoch 28/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1175 - mean_absolute_error: 0.2001 - val_loss: 0.1430 - val_mean_absolute_error: 0.2430
# Epoch 29/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.1172 - mean_absolute_error: 0.1974 - val_loss: 0.1362 - val_mean_absolute_error: 0.2322
# Epoch 30/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1163 - mean_absolute_error: 0.1997 - val_loss: 0.1319 - val_mean_absolute_error: 0.2325
# Epoch 31/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.1150 - mean_absolute_error: 0.1975 - val_loss: 0.1456 - val_mean_absolute_error: 0.2533
# Epoch 32/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1167 - mean_absolute_error: 0.2004 - val_loss: 0.1357 - val_mean_absolute_error: 0.2419
# Epoch 33/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1134 - mean_absolute_error: 0.1928 - val_loss: 0.1296 - val_mean_absolute_error: 0.2281
# Epoch 34/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1124 - mean_absolute_error: 0.1939 - val_loss: 0.1295 - val_mean_absolute_error: 0.2233
# Epoch 35/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1119 - mean_absolute_error: 0.1929 - val_loss: 0.1266 - val_mean_absolute_error: 0.2169
# Epoch 36/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1127 - mean_absolute_error: 0.1943 - val_loss: 0.1247 - val_mean_absolute_error: 0.2178
# Epoch 37/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1111 - mean_absolute_error: 0.1988 - val_loss: 0.1312 - val_mean_absolute_error: 0.2283
# Epoch 38/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1146 - mean_absolute_error: 0.2016 - val_loss: 0.1284 - val_mean_absolute_error: 0.2244
# Epoch 39/500
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1107 - mean_absolute_error: 0.1901 - val_loss: 0.1306 - val_mean_absolute_error: 0.2373
# Epoch 40/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.1142 - mean_absolute_error: 0.2061 - val_loss: 0.1257 - val_mean_absolute_error: 0.2216
# Epoch 41/500
# 19/19 [==============================] - 0s 25ms/step - loss: 0.1089 - mean_absolute_error: 0.1889 - val_loss: 0.1215 - val_mean_absolute_error: 0.2089
# Epoch 42/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1096 - mean_absolute_error: 0.1981 - val_loss: 0.1246 - val_mean_absolute_error: 0.2151
# Epoch 43/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1058 - mean_absolute_error: 0.1860 - val_loss: 0.1285 - val_mean_absolute_error: 0.2276
# Epoch 44/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.1083 - mean_absolute_error: 0.1982 - val_loss: 0.1295 - val_mean_absolute_error: 0.2305
# Epoch 45/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1073 - mean_absolute_error: 0.1934 - val_loss: 0.1215 - val_mean_absolute_error: 0.2158
# Epoch 46/500
# 19/19 [==============================] - 0s 24ms/step - loss: 0.1040 - mean_absolute_error: 0.1861 - val_loss: 0.1251 - val_mean_absolute_error: 0.2147
# Epoch 47/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1048 - mean_absolute_error: 0.1923 - val_loss: 0.1245 - val_mean_absolute_error: 0.2115
# Epoch 48/500
# 19/19 [==============================] - 0s 24ms/step - loss: 0.1050 - mean_absolute_error: 0.1905 - val_loss: 0.1232 - val_mean_absolute_error: 0.2207
# Epoch 49/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.1059 - mean_absolute_error: 0.1921 - val_loss: 0.1214 - val_mean_absolute_error: 0.2156
# Epoch 50/500
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1119 - mean_absolute_error: 0.2073 - val_loss: 0.1132 - val_mean_absolute_error: 0.1993
# Epoch 51/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.1041 - mean_absolute_error: 0.1910 - val_loss: 0.1198 - val_mean_absolute_error: 0.2059
# Epoch 52/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1017 - mean_absolute_error: 0.1869 - val_loss: 0.1253 - val_mean_absolute_error: 0.2135
# Epoch 53/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1004 - mean_absolute_error: 0.1851 - val_loss: 0.1225 - val_mean_absolute_error: 0.2172
# Epoch 54/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.0983 - mean_absolute_error: 0.1837 - val_loss: 0.1192 - val_mean_absolute_error: 0.2072
# Epoch 55/500
# 19/19 [==============================] - 0s 23ms/step - loss: 0.0986 - mean_absolute_error: 0.1830 - val_loss: 0.1232 - val_mean_absolute_error: 0.2221
# Epoch 56/500
# 19/19 [==============================] - 0s 23ms/step - loss: 0.0977 - mean_absolute_error: 0.1787 - val_loss: 0.1229 - val_mean_absolute_error: 0.2131
# Epoch 57/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0987 - mean_absolute_error: 0.1891 - val_loss: 0.1166 - val_mean_absolute_error: 0.2021
# Epoch 58/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.0958 - mean_absolute_error: 0.1855 - val_loss: 0.1196 - val_mean_absolute_error: 0.2170
# Epoch 59/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.0965 - mean_absolute_error: 0.1855 - val_loss: 0.1172 - val_mean_absolute_error: 0.2051
# Epoch 60/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.0952 - mean_absolute_error: 0.1812 - val_loss: 0.1167 - val_mean_absolute_error: 0.2011
# Epoch 61/500
# 19/19 [==============================] - 0s 23ms/step - loss: 0.0943 - mean_absolute_error: 0.1801 - val_loss: 0.1196 - val_mean_absolute_error: 0.2083
# Epoch 62/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0951 - mean_absolute_error: 0.1822 - val_loss: 0.1230 - val_mean_absolute_error: 0.2159
# Epoch 63/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0942 - mean_absolute_error: 0.1843 - val_loss: 0.1171 - val_mean_absolute_error: 0.2011
# Epoch 64/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0917 - mean_absolute_error: 0.1816 - val_loss: 0.1330 - val_mean_absolute_error: 0.2251
# Epoch 65/500
# 19/19 [==============================] - 0s 24ms/step - loss: 0.0923 - mean_absolute_error: 0.1816 - val_loss: 0.1177 - val_mean_absolute_error: 0.2027
# Epoch 66/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0906 - mean_absolute_error: 0.1754 - val_loss: 0.1292 - val_mean_absolute_error: 0.2215
# Epoch 67/500
# 19/19 [==============================] - 0s 24ms/step - loss: 0.0898 - mean_absolute_error: 0.1789 - val_loss: 0.1292 - val_mean_absolute_error: 0.2131
# Epoch 68/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.0883 - mean_absolute_error: 0.1773 - val_loss: 0.1243 - val_mean_absolute_error: 0.2279
# Epoch 69/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0920 - mean_absolute_error: 0.1814 - val_loss: 0.1241 - val_mean_absolute_error: 0.2201
# Epoch 70/500
# 19/19 [==============================] - 0s 24ms/step - loss: 0.0869 - mean_absolute_error: 0.1714 - val_loss: 0.1228 - val_mean_absolute_error: 0.2189

# %%
plot_test(test_x[1], test_y[1], model=multi_lstm_model)
preds = multi_lstm_model(test_x)

m = tf.keras.metrics.MeanAbsolutePercentageError()
m.update_state(test_y, preds)
print('MAPE :',m.result().numpy(),'%')
# Out:
# MAPE : 60.827038 %

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
CONV_WIDTH = 3
multi_conv_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, CONV_WIDTH, features]
    tf.keras.layers.Lambda(lambda x: x[:, -CONV_WIDTH:, :]),
    # Shape => [batch, 1, conv_units]
    tf.keras.layers.Conv1D(256, activation='relu', kernel_size=(CONV_WIDTH)),
    # Shape => [batch, 1,  out_steps*features]
    tf.keras.layers.Dense(FORECAST_SIZE*NUM_FEATURES,
                          kernel_initializer=tf.initializers.zeros()),
    # Shape => [batch, out_steps, features]
    tf.keras.layers.Reshape([FORECAST_SIZE, NUM_FEATURES])
])

history = compile_and_fit(
    multi_conv_model,
    200,
    train_x,
    train_y,
    val_x,
    val_y)

# %%
plot_test(test_x[0], test_y[0], model=multi_conv_model)
preds = multi_conv_model(test_x)

m = tf.keras.metrics.MeanAbsolutePercentageError()
m.update_state(test_y, preds)
print('MAPE :',m.result().numpy(),'%')

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
