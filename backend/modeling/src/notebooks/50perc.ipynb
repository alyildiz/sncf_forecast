# %%
from src.extract_data import load_data, process_data
from src.utils import get_test_set
import pandas as pd
from src.constants import FILE_PATH
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
import numpy as np 
import seaborn as sns
set_matplotlib_formats('svg')
import tensorflow as tf
import IPython
import IPython.display

from src.utils import build_time_series
# Out:
# /tmp/ipykernel_1352/829871368.py:9: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')

# %%
def plot_test(x_test, y_test, model = None):
    y_test = y_test.reshape(y_test.shape[0], -1)
    fix, ax = plt.subplots(y_test.shape[1] , 1, figsize=(10,7))
    
    if y_test.shape[1] == 1:
        historical_index = [x for x in range(x_test.shape[0])]
        pred_index = [x+x_test.shape[0] for x in range(y_test.shape[0])]

        ax.plot(historical_index, x_test[:, 0], marker='.', label='Input')
        ax.scatter(pred_index, y_test[:, 0], edgecolors='k', label='Labels', c='#2ca02c', s=32)

        if model is not None:
            preds = model(np.expand_dims(x_test, axis=0))[0]
            ax.scatter(pred_index, preds[:, 0],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)
            
    else:
        for i in range(y_test.shape[1]):
            historical_index = [x for x in range(x_test.shape[0])]
            pred_index = [x+x_test.shape[0] for x in range(y_test.shape[0])]

            ax[i].plot(historical_index, x_test[:, i], marker='.', label='Input')
            ax[i].scatter(pred_index, y_test[:, i], edgecolors='k', label='Labels', c='#2ca02c', s=32)

            if model is not None:
                preds = model(np.expand_dims(x_test, axis=0))[0]
                ax[i].scatter(pred_index, preds[:, i],
                      marker='X', edgecolors='k', label='Predictions',
                      c='#ff7f0e', s=64)
    
    plt.legend()

# %%
FORECAST_SIZE = 5
WINDOW_SIZE = FORECAST_SIZE * 10
NUM_FEATURES = 1

# %%
df = load_data(FILE_PATH)
df = process_data(df, use_covariates=False)
#df = df.drop(['day_of_month', 'month'], axis=1)

# %%
df.head()
# Out:
#             nbr_travels  nbr_late_trains
# date
# 2019-03-01        18680             1799
# 2019-03-02        12341             1049
# 2019-03-03        10839              969
# 2019-03-04        18502             2228
# 2019-03-05        18373             1767

# %%
n = len(df)
train_df = df[0:int(n*0.7)].astype(float)
val_df = df[int(n*0.7):int(n*0.9)].astype(float)
test_df = df[int(n*0.9):].astype(float)

# %%
def normalize(data):
    dic = {}
    for col in ['nbr_travels', 'nbr_late_trains']:
        data_mean = data[col].mean()
        data_std = data[col].std()
        dic[col] = [data_mean, data_std]
    return dic

dic = normalize(train_df)

# %%
train_df['nbr_travels'] = (train_df['nbr_travels'] - dic['nbr_travels'][0]) / dic['nbr_travels'][1]
train_df['nbr_late_trains'] = (train_df['nbr_late_trains'] - dic['nbr_late_trains'][0]) / dic['nbr_late_trains'][1]

val_df['nbr_travels'] = (val_df['nbr_travels'] - dic['nbr_travels'][0]) / dic['nbr_travels'][1]
val_df['nbr_late_trains'] = (val_df['nbr_late_trains'] - dic['nbr_late_trains'][0]) / dic['nbr_late_trains'][1]

test_df['nbr_travels'] = (test_df['nbr_travels'] - dic['nbr_travels'][0]) / dic['nbr_travels'][1]
test_df['nbr_late_trains'] = (test_df['nbr_late_trains'] - dic['nbr_late_trains'][0]) / dic['nbr_late_trains'][1]

# %%
#train_df = train_df.drop('nbr_late_trains', axis=1)
#val_df = val_df.drop('nbr_late_trains', axis=1)
#test_df = test_df.drop('nbr_late_trains', axis=1)


train_df.head()
# Out:
#             nbr_travels  nbr_late_trains
# date
# 2019-03-01     1.256222         0.793774
# 2019-03-02    -0.239490        -0.356145
# 2019-03-03    -0.593893        -0.478803
# 2019-03-04     1.214223         1.451528
# 2019-03-05     1.183785         0.744711

# %%
train_x, train_y = build_time_series(train_df, window_size=WINDOW_SIZE, forecast_size=FORECAST_SIZE)
val_x, val_y = build_time_series(val_df, window_size=WINDOW_SIZE, forecast_size=FORECAST_SIZE)
test_x, test_y = build_time_series(test_df, window_size=WINDOW_SIZE, forecast_size=FORECAST_SIZE)

train_y = train_y[:, :, 0]
val_y = val_y[:, :, 0]
test_y = test_y[:, :, 0]

# %%
plot_test(test_x[0], test_y[0])

# %%
def compile_and_fit(model, max_epochs, train_x, train_y, val_x, val_y, patience=30):
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')
    model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(learning_rate=0.001),
                metrics=[tf.metrics.MeanAbsoluteError()])
    
    history = model.fit(train_x, 
                        train_y,
                        batch_size=64,
                        epochs=max_epochs,
                        validation_data=(val_x, val_y),
                        callbacks=[early_stopping])
    return history

# %%
multi_lstm_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, lstm_units].
    # Adding more `lstm_units` just overfits more quickly.
    tf.keras.layers.GRU(128, return_sequences=False),
    tf.keras.layers.Dropout(.2),
    tf.keras.layers.Dense(FORECAST_SIZE*NUM_FEATURES),
    # Shape => [batch, out_steps, features].
    tf.keras.layers.Reshape([FORECAST_SIZE, NUM_FEATURES])
])

history = compile_and_fit(
    multi_lstm_model,
    500,
    train_x,
    train_y,
    val_x,
    val_y)

#IPython.display.clear_output()
# Out:
# Epoch 1/500
# 10/10 [==============================] - 2s 75ms/step - loss: 0.7458 - mean_absolute_error: 0.7731 - val_loss: 0.5691 - val_mean_absolute_error: 0.7122
# Epoch 2/500
# 10/10 [==============================] - 0s 36ms/step - loss: 0.5586 - mean_absolute_error: 0.6474 - val_loss: 0.4977 - val_mean_absolute_error: 0.6601
# Epoch 3/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.5316 - mean_absolute_error: 0.6395 - val_loss: 0.4821 - val_mean_absolute_error: 0.6532
# Epoch 4/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.5019 - mean_absolute_error: 0.6160 - val_loss: 0.4153 - val_mean_absolute_error: 0.5894
# Epoch 5/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4691 - mean_absolute_error: 0.5917 - val_loss: 0.3763 - val_mean_absolute_error: 0.5544
# Epoch 6/500
# 10/10 [==============================] - 0s 37ms/step - loss: 0.4348 - mean_absolute_error: 0.5632 - val_loss: 0.3295 - val_mean_absolute_error: 0.4829
# Epoch 7/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.3898 - mean_absolute_error: 0.5143 - val_loss: 0.2980 - val_mean_absolute_error: 0.4421
# Epoch 8/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.3561 - mean_absolute_error: 0.4804 - val_loss: 0.2656 - val_mean_absolute_error: 0.4137
# Epoch 9/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.3381 - mean_absolute_error: 0.4632 - val_loss: 0.2546 - val_mean_absolute_error: 0.4038
# Epoch 10/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.3117 - mean_absolute_error: 0.4391 - val_loss: 0.2435 - val_mean_absolute_error: 0.3900
# Epoch 11/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2959 - mean_absolute_error: 0.4228 - val_loss: 0.2239 - val_mean_absolute_error: 0.3742
# Epoch 12/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2803 - mean_absolute_error: 0.4046 - val_loss: 0.2170 - val_mean_absolute_error: 0.3597
# Epoch 13/500
# 10/10 [==============================] - 0s 36ms/step - loss: 0.2628 - mean_absolute_error: 0.3857 - val_loss: 0.2124 - val_mean_absolute_error: 0.3569
# Epoch 14/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2382 - mean_absolute_error: 0.3585 - val_loss: 0.1833 - val_mean_absolute_error: 0.3202
# Epoch 15/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2111 - mean_absolute_error: 0.3296 - val_loss: 0.1556 - val_mean_absolute_error: 0.2776
# Epoch 16/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2017 - mean_absolute_error: 0.3196 - val_loss: 0.1410 - val_mean_absolute_error: 0.2574
# Epoch 17/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1873 - mean_absolute_error: 0.3060 - val_loss: 0.1424 - val_mean_absolute_error: 0.2634
# Epoch 18/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1809 - mean_absolute_error: 0.3001 - val_loss: 0.1413 - val_mean_absolute_error: 0.2492
# Epoch 19/500
# 10/10 [==============================] - 0s 41ms/step - loss: 0.1701 - mean_absolute_error: 0.2875 - val_loss: 0.1463 - val_mean_absolute_error: 0.2573
# Epoch 20/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1682 - mean_absolute_error: 0.2809 - val_loss: 0.1496 - val_mean_absolute_error: 0.2574
# Epoch 21/500
# 10/10 [==============================] - 0s 40ms/step - loss: 0.1690 - mean_absolute_error: 0.2825 - val_loss: 0.1519 - val_mean_absolute_error: 0.2614
# Epoch 22/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1656 - mean_absolute_error: 0.2803 - val_loss: 0.1659 - val_mean_absolute_error: 0.2782
# Epoch 23/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1659 - mean_absolute_error: 0.2750 - val_loss: 0.1469 - val_mean_absolute_error: 0.2516
# Epoch 24/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1619 - mean_absolute_error: 0.2749 - val_loss: 0.1671 - val_mean_absolute_error: 0.2859
# Epoch 25/500
# 10/10 [==============================] - 0s 37ms/step - loss: 0.1649 - mean_absolute_error: 0.2799 - val_loss: 0.1366 - val_mean_absolute_error: 0.2395
# Epoch 26/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1608 - mean_absolute_error: 0.2759 - val_loss: 0.1530 - val_mean_absolute_error: 0.2617
# Epoch 27/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1508 - mean_absolute_error: 0.2631 - val_loss: 0.1440 - val_mean_absolute_error: 0.2519
# Epoch 28/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1542 - mean_absolute_error: 0.2646 - val_loss: 0.1480 - val_mean_absolute_error: 0.2589
# Epoch 29/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1508 - mean_absolute_error: 0.2624 - val_loss: 0.1479 - val_mean_absolute_error: 0.2602
# Epoch 30/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1493 - mean_absolute_error: 0.2581 - val_loss: 0.1402 - val_mean_absolute_error: 0.2506
# Epoch 31/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1486 - mean_absolute_error: 0.2531 - val_loss: 0.1278 - val_mean_absolute_error: 0.2270
# Epoch 32/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1461 - mean_absolute_error: 0.2510 - val_loss: 0.1348 - val_mean_absolute_error: 0.2397
# Epoch 33/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1447 - mean_absolute_error: 0.2513 - val_loss: 0.1421 - val_mean_absolute_error: 0.2468
# Epoch 34/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1434 - mean_absolute_error: 0.2445 - val_loss: 0.1412 - val_mean_absolute_error: 0.2533
# Epoch 35/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1394 - mean_absolute_error: 0.2471 - val_loss: 0.1529 - val_mean_absolute_error: 0.2630
# Epoch 36/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1386 - mean_absolute_error: 0.2466 - val_loss: 0.1689 - val_mean_absolute_error: 0.2819
# Epoch 37/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1402 - mean_absolute_error: 0.2417 - val_loss: 0.1284 - val_mean_absolute_error: 0.2269
# Epoch 38/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1408 - mean_absolute_error: 0.2442 - val_loss: 0.1368 - val_mean_absolute_error: 0.2377
# Epoch 39/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1421 - mean_absolute_error: 0.2462 - val_loss: 0.1378 - val_mean_absolute_error: 0.2457
# Epoch 40/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1395 - mean_absolute_error: 0.2559 - val_loss: 0.1623 - val_mean_absolute_error: 0.2811
# Epoch 41/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1506 - mean_absolute_error: 0.2590 - val_loss: 0.1278 - val_mean_absolute_error: 0.2297
# Epoch 42/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1437 - mean_absolute_error: 0.2487 - val_loss: 0.1315 - val_mean_absolute_error: 0.2374
# Epoch 43/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1376 - mean_absolute_error: 0.2423 - val_loss: 0.1486 - val_mean_absolute_error: 0.2555
# Epoch 44/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1367 - mean_absolute_error: 0.2417 - val_loss: 0.1496 - val_mean_absolute_error: 0.2573
# Epoch 45/500
# 10/10 [==============================] - 0s 37ms/step - loss: 0.1335 - mean_absolute_error: 0.2363 - val_loss: 0.1374 - val_mean_absolute_error: 0.2426
# Epoch 46/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1317 - mean_absolute_error: 0.2360 - val_loss: 0.1481 - val_mean_absolute_error: 0.2556
# Epoch 47/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1296 - mean_absolute_error: 0.2329 - val_loss: 0.1337 - val_mean_absolute_error: 0.2338
# Epoch 48/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1328 - mean_absolute_error: 0.2340 - val_loss: 0.1366 - val_mean_absolute_error: 0.2409
# Epoch 49/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1329 - mean_absolute_error: 0.2396 - val_loss: 0.1503 - val_mean_absolute_error: 0.2584
# Epoch 50/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1330 - mean_absolute_error: 0.2339 - val_loss: 0.1386 - val_mean_absolute_error: 0.2459
# Epoch 51/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1278 - mean_absolute_error: 0.2302 - val_loss: 0.1461 - val_mean_absolute_error: 0.2527
# Epoch 52/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1296 - mean_absolute_error: 0.2347 - val_loss: 0.1437 - val_mean_absolute_error: 0.2476
# Epoch 53/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1294 - mean_absolute_error: 0.2315 - val_loss: 0.1419 - val_mean_absolute_error: 0.2455
# Epoch 54/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1282 - mean_absolute_error: 0.2299 - val_loss: 0.1391 - val_mean_absolute_error: 0.2412
# Epoch 55/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1320 - mean_absolute_error: 0.2383 - val_loss: 0.1485 - val_mean_absolute_error: 0.2578
# Epoch 56/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1298 - mean_absolute_error: 0.2372 - val_loss: 0.1458 - val_mean_absolute_error: 0.2519
# Epoch 57/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1270 - mean_absolute_error: 0.2309 - val_loss: 0.1302 - val_mean_absolute_error: 0.2327
# Epoch 58/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1285 - mean_absolute_error: 0.2367 - val_loss: 0.1366 - val_mean_absolute_error: 0.2352
# Epoch 59/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1245 - mean_absolute_error: 0.2253 - val_loss: 0.1275 - val_mean_absolute_error: 0.2270
# Epoch 60/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1225 - mean_absolute_error: 0.2266 - val_loss: 0.1252 - val_mean_absolute_error: 0.2149
# Epoch 61/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1267 - mean_absolute_error: 0.2331 - val_loss: 0.1314 - val_mean_absolute_error: 0.2332
# Epoch 62/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1290 - mean_absolute_error: 0.2371 - val_loss: 0.1288 - val_mean_absolute_error: 0.2264
# Epoch 63/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1193 - mean_absolute_error: 0.2203 - val_loss: 0.1221 - val_mean_absolute_error: 0.2177
# Epoch 64/500
# 10/10 [==============================] - 0s 37ms/step - loss: 0.1224 - mean_absolute_error: 0.2290 - val_loss: 0.1131 - val_mean_absolute_error: 0.2009
# Epoch 65/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1208 - mean_absolute_error: 0.2240 - val_loss: 0.1240 - val_mean_absolute_error: 0.2205
# Epoch 66/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1208 - mean_absolute_error: 0.2291 - val_loss: 0.1181 - val_mean_absolute_error: 0.2120
# Epoch 67/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1185 - mean_absolute_error: 0.2247 - val_loss: 0.1185 - val_mean_absolute_error: 0.2101
# Epoch 68/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1180 - mean_absolute_error: 0.2234 - val_loss: 0.1123 - val_mean_absolute_error: 0.2014
# Epoch 69/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1197 - mean_absolute_error: 0.2234 - val_loss: 0.1186 - val_mean_absolute_error: 0.2088
# Epoch 70/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1205 - mean_absolute_error: 0.2243 - val_loss: 0.1144 - val_mean_absolute_error: 0.2051
# Epoch 71/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1169 - mean_absolute_error: 0.2225 - val_loss: 0.1102 - val_mean_absolute_error: 0.1918
# Epoch 72/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1221 - mean_absolute_error: 0.2275 - val_loss: 0.1158 - val_mean_absolute_error: 0.2050
# Epoch 73/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1221 - mean_absolute_error: 0.2270 - val_loss: 0.1085 - val_mean_absolute_error: 0.1914
# Epoch 74/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1188 - mean_absolute_error: 0.2220 - val_loss: 0.1195 - val_mean_absolute_error: 0.2078
# Epoch 75/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1180 - mean_absolute_error: 0.2259 - val_loss: 0.1176 - val_mean_absolute_error: 0.1956
# Epoch 76/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1168 - mean_absolute_error: 0.2199 - val_loss: 0.1218 - val_mean_absolute_error: 0.2010
# Epoch 77/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1120 - mean_absolute_error: 0.2151 - val_loss: 0.1214 - val_mean_absolute_error: 0.2183
# Epoch 78/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1162 - mean_absolute_error: 0.2274 - val_loss: 0.1166 - val_mean_absolute_error: 0.2036
# Epoch 79/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1132 - mean_absolute_error: 0.2114 - val_loss: 0.1200 - val_mean_absolute_error: 0.2090
# Epoch 80/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1113 - mean_absolute_error: 0.2142 - val_loss: 0.1231 - val_mean_absolute_error: 0.2109
# Epoch 81/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1169 - mean_absolute_error: 0.2239 - val_loss: 0.1164 - val_mean_absolute_error: 0.2061
# Epoch 82/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1070 - mean_absolute_error: 0.2185 - val_loss: 0.1161 - val_mean_absolute_error: 0.1988
# Epoch 83/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1111 - mean_absolute_error: 0.2143 - val_loss: 0.1093 - val_mean_absolute_error: 0.1996
# Epoch 84/500
# 10/10 [==============================] - 0s 37ms/step - loss: 0.1096 - mean_absolute_error: 0.2178 - val_loss: 0.1186 - val_mean_absolute_error: 0.2068
# Epoch 85/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1110 - mean_absolute_error: 0.2167 - val_loss: 0.1482 - val_mean_absolute_error: 0.2493
# Epoch 86/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1376 - mean_absolute_error: 0.2511 - val_loss: 0.1239 - val_mean_absolute_error: 0.2065
# Epoch 87/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1172 - mean_absolute_error: 0.2316 - val_loss: 0.1248 - val_mean_absolute_error: 0.2133
# Epoch 88/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1083 - mean_absolute_error: 0.2137 - val_loss: 0.1132 - val_mean_absolute_error: 0.1950
# Epoch 89/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1042 - mean_absolute_error: 0.2072 - val_loss: 0.1206 - val_mean_absolute_error: 0.2066
# Epoch 90/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1029 - mean_absolute_error: 0.2092 - val_loss: 0.1243 - val_mean_absolute_error: 0.2151
# Epoch 91/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1057 - mean_absolute_error: 0.2129 - val_loss: 0.1148 - val_mean_absolute_error: 0.2025
# Epoch 92/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1029 - mean_absolute_error: 0.2041 - val_loss: 0.1326 - val_mean_absolute_error: 0.2228
# Epoch 93/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0983 - mean_absolute_error: 0.2046 - val_loss: 0.1158 - val_mean_absolute_error: 0.2031
# Epoch 94/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0984 - mean_absolute_error: 0.2059 - val_loss: 0.1134 - val_mean_absolute_error: 0.2031
# Epoch 95/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0982 - mean_absolute_error: 0.2042 - val_loss: 0.1253 - val_mean_absolute_error: 0.2151
# Epoch 96/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1043 - mean_absolute_error: 0.2154 - val_loss: 0.1280 - val_mean_absolute_error: 0.2112
# Epoch 97/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1018 - mean_absolute_error: 0.2071 - val_loss: 0.1171 - val_mean_absolute_error: 0.2054
# Epoch 98/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1027 - mean_absolute_error: 0.2139 - val_loss: 0.1102 - val_mean_absolute_error: 0.2021
# Epoch 99/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1048 - mean_absolute_error: 0.2191 - val_loss: 0.1147 - val_mean_absolute_error: 0.2056
# Epoch 100/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0993 - mean_absolute_error: 0.2039 - val_loss: 0.1209 - val_mean_absolute_error: 0.2074
# Epoch 101/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0968 - mean_absolute_error: 0.2012 - val_loss: 0.1189 - val_mean_absolute_error: 0.2059
# Epoch 102/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0977 - mean_absolute_error: 0.1967 - val_loss: 0.1373 - val_mean_absolute_error: 0.2265
# Epoch 103/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0985 - mean_absolute_error: 0.2064 - val_loss: 0.1135 - val_mean_absolute_error: 0.2021

# %%
idx=0
plot_test(test_x[idx], test_y[idx], model=multi_lstm_model)
preds = multi_lstm_model(test_x)

m = tf.keras.metrics.MeanAbsolutePercentageError()
m.update_state(test_y, preds)
print('MAPE :',m.result().numpy(),'%')
# Out:
# MAPE : 49.4713 %

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_absolute_error

preds = model(test_x)

mape = mean_absolute_percentage_error(np.array(preds).reshape(37,5), test_y)
mse = mean_squared_error(np.array(preds).reshape(37,5), test_y)
mae = mean_absolute_error(np.array(preds).reshape(37,5), test_y)

print('MAPE :', round(mape *100,2) ,'%')
print('MSE :', round(mse,2))
print('MAE :', round(mae,2))

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
CONV_WIDTH = 5
multi_conv_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, CONV_WIDTH, features]
    tf.keras.layers.Lambda(lambda x: x[:, -CONV_WIDTH:, :]),
    # Shape => [batch, 1, conv_units]
    tf.keras.layers.Conv1D(128, activation='relu', kernel_size=(CONV_WIDTH)),
    # Shape => [batch, 1,  out_steps*features]
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(FORECAST_SIZE*NUM_FEATURES,
                          kernel_initializer=tf.initializers.zeros()),
    # Shape => [batch, out_steps, features]
    tf.keras.layers.Reshape([FORECAST_SIZE, NUM_FEATURES])
])

history = compile_and_fit(
    multi_conv_model,
    500,
    train_x,
    train_y,
    val_x,
    val_y)

# %%
plot_test(test_x[0], test_y[0], model=multi_conv_model)
preds = multi_conv_model(test_x)

m = tf.keras.metrics.MeanAbsolutePercentageError()
m.update_state(test_y, preds)
print('MAPE :',m.result().numpy(),'%')

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
