# %%
from src.extract_data import load_data, process_data
from src.utils import get_test_set
import pandas as pd
from src.constants import FILE_PATH
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
import numpy as np 
import seaborn as sns
set_matplotlib_formats('svg')
import tensorflow as tf
import IPython
import IPython.display

from src.utils import build_time_series
# Out:
# /tmp/ipykernel_2018/829871368.py:9: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')
# 2021-08-29 11:23:59.875488: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-08-29 11:23:59.875511: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
def plot_test(x_test, y_test, model = None):
    y_test = y_test.reshape(y_test.shape[0], -1)
    fix, ax = plt.subplots(y_test.shape[1] , 1, figsize=(10,7))
    
    if y_test.shape[1] == 1:
        historical_index = [x for x in range(x_test.shape[0])]
        pred_index = [x+x_test.shape[0] for x in range(y_test.shape[0])]

        ax.plot(historical_index, x_test[:, 0], marker='.', label='Input')
        ax.scatter(pred_index, y_test[:, 0], edgecolors='k', label='Labels', c='#2ca02c', s=32)

        if model is not None:
            preds = model(np.expand_dims(x_test, axis=0))[0]
            ax.scatter(pred_index, preds[:, 0],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)
            
    else:
        for i in range(y_test.shape[1]):
            historical_index = [x for x in range(x_test.shape[0])]
            pred_index = [x+x_test.shape[0] for x in range(y_test.shape[0])]

            ax[i].plot(historical_index, x_test[:, i], marker='.', label='Input')
            ax[i].scatter(pred_index, y_test[:, i], edgecolors='k', label='Labels', c='#2ca02c', s=32)

            if model is not None:
                preds = model(np.expand_dims(x_test, axis=0))[0]
                ax[i].scatter(pred_index, preds[:, i],
                      marker='X', edgecolors='k', label='Predictions',
                      c='#ff7f0e', s=64)
    
    plt.legend()

# %%
FORECAST_SIZE = 5
WINDOW_SIZE = FORECAST_SIZE * 10
NUM_FEATURES = 1

# %%
df = load_data(FILE_PATH)
df = process_data(df, use_covariates=False)
#df = df.drop(['day_of_month', 'month'], axis=1)

# %%
df.head()
# Out:
#             nbr_travels  nbr_late_trains
# date
# 2019-03-01        18680             1799
# 2019-03-02        12341             1049
# 2019-03-03        10839              969
# 2019-03-04        18502             2228
# 2019-03-05        18373             1767

# %%
n = len(df)
train_df = df[0:int(n*0.7)].astype(float)
val_df = df[int(n*0.7):int(n*0.9)].astype(float)
test_df = df[int(n*0.9):].astype(float)

# %%
def normalize(data):
    dic = {}
    for col in ['nbr_travels', 'nbr_late_trains']:
        data_mean = data[col].mean()
        data_std = data[col].std()
        dic[col] = [data_mean, data_std]
    return dic

dic = normalize(train_df)

# %%
train_df['nbr_travels'] = (train_df['nbr_travels'] - dic['nbr_travels'][0]) / dic['nbr_travels'][1]
train_df['nbr_late_trains'] = (train_df['nbr_late_trains'] - dic['nbr_late_trains'][0]) / dic['nbr_late_trains'][1]

val_df['nbr_travels'] = (val_df['nbr_travels'] - dic['nbr_travels'][0]) / dic['nbr_travels'][1]
val_df['nbr_late_trains'] = (val_df['nbr_late_trains'] - dic['nbr_late_trains'][0]) / dic['nbr_late_trains'][1]

test_df['nbr_travels'] = (test_df['nbr_travels'] - dic['nbr_travels'][0]) / dic['nbr_travels'][1]
test_df['nbr_late_trains'] = (test_df['nbr_late_trains'] - dic['nbr_late_trains'][0]) / dic['nbr_late_trains'][1]

# %%
#train_df = train_df.drop('nbr_late_trains', axis=1)
#val_df = val_df.drop('nbr_late_trains', axis=1)
#test_df = test_df.drop('nbr_late_trains', axis=1)


train_df.head()
# Out:
#             nbr_travels  nbr_late_trains
# date
# 2019-03-01     1.256222         0.793774
# 2019-03-02    -0.239490        -0.356145
# 2019-03-03    -0.593893        -0.478803
# 2019-03-04     1.214223         1.451528
# 2019-03-05     1.183785         0.744711

# %%
train_x, train_y = build_time_series(train_df, window_size=WINDOW_SIZE, forecast_size=FORECAST_SIZE)
val_x, val_y = build_time_series(val_df, window_size=WINDOW_SIZE, forecast_size=FORECAST_SIZE)
test_x, test_y = build_time_series(test_df, window_size=WINDOW_SIZE, forecast_size=FORECAST_SIZE)

train_y = train_y[:, :, 0]
val_y = val_y[:, :, 0]
test_y = test_y[:, :, 0]

# %%
plot_test(test_x[0], test_y[0])

# %%
def compile_and_fit(model, max_epochs, train_x, train_y, val_x, val_y, patience=40):
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')
    model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(),
                metrics=[tf.metrics.MeanAbsoluteError()])
    
    history = model.fit(train_x, train_y, epochs=max_epochs,
                      validation_data=(val_x, val_y),
                      callbacks=[early_stopping])
    return history

# %%
multi_lstm_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, lstm_units].
    # Adding more `lstm_units` just overfits more quickly.
    tf.keras.layers.GRU(128, return_sequences=False),

    tf.keras.layers.Dense(FORECAST_SIZE*NUM_FEATURES),
    # Shape => [batch, out_steps, features].
    tf.keras.layers.Reshape([FORECAST_SIZE, NUM_FEATURES])
])

history = compile_and_fit(
    multi_lstm_model,
    500,
    train_x,
    train_y,
    val_x,
    val_y)

#IPython.display.clear_output()
# Out:
# 2021-08-29 11:24:12.106469: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-08-29 11:24:12.106489: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-08-29 11:24:12.106504: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (8e05c53b2018): /proc/driver/nvidia/version does not exist
# 2021-08-29 11:24:12.157128: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/500
# 19/19 [==============================] - 3s 55ms/step - loss: 0.6942 - mean_absolute_error: 0.7420 - val_loss: 0.5492 - val_mean_absolute_error: 0.6902
# Epoch 2/500
# 19/19 [==============================] - 1s 39ms/step - loss: 0.5291 - mean_absolute_error: 0.6329 - val_loss: 0.4339 - val_mean_absolute_error: 0.6095
# Epoch 3/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.4552 - mean_absolute_error: 0.5764 - val_loss: 0.3461 - val_mean_absolute_error: 0.5133
# Epoch 4/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.3705 - mean_absolute_error: 0.5085 - val_loss: 0.2859 - val_mean_absolute_error: 0.4289
# Epoch 5/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.3265 - mean_absolute_error: 0.4541 - val_loss: 0.2854 - val_mean_absolute_error: 0.4232
# Epoch 6/500
# 19/19 [==============================] - 1s 33ms/step - loss: 0.2971 - mean_absolute_error: 0.4258 - val_loss: 0.2340 - val_mean_absolute_error: 0.3771
# Epoch 7/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.2606 - mean_absolute_error: 0.3812 - val_loss: 0.2206 - val_mean_absolute_error: 0.3661
# Epoch 8/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.2191 - mean_absolute_error: 0.3380 - val_loss: 0.1818 - val_mean_absolute_error: 0.3175
# Epoch 9/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.1785 - mean_absolute_error: 0.2931 - val_loss: 0.1818 - val_mean_absolute_error: 0.3027
# Epoch 10/500
# 19/19 [==============================] - 1s 33ms/step - loss: 0.1586 - mean_absolute_error: 0.2663 - val_loss: 0.1673 - val_mean_absolute_error: 0.2845
# Epoch 11/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.1481 - mean_absolute_error: 0.2518 - val_loss: 0.1419 - val_mean_absolute_error: 0.2443
# Epoch 12/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.1421 - mean_absolute_error: 0.2448 - val_loss: 0.1461 - val_mean_absolute_error: 0.2641
# Epoch 13/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.1428 - mean_absolute_error: 0.2487 - val_loss: 0.1348 - val_mean_absolute_error: 0.2329
# Epoch 14/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.1329 - mean_absolute_error: 0.2243 - val_loss: 0.1394 - val_mean_absolute_error: 0.2411
# Epoch 15/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.1332 - mean_absolute_error: 0.2262 - val_loss: 0.1309 - val_mean_absolute_error: 0.2306
# Epoch 16/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.1304 - mean_absolute_error: 0.2273 - val_loss: 0.1559 - val_mean_absolute_error: 0.2658
# Epoch 17/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.1267 - mean_absolute_error: 0.2148 - val_loss: 0.1433 - val_mean_absolute_error: 0.2453
# Epoch 18/500
# 19/19 [==============================] - 1s 33ms/step - loss: 0.1232 - mean_absolute_error: 0.2123 - val_loss: 0.1374 - val_mean_absolute_error: 0.2331
# Epoch 19/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.1212 - mean_absolute_error: 0.2046 - val_loss: 0.1611 - val_mean_absolute_error: 0.2741
# Epoch 20/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.1210 - mean_absolute_error: 0.2069 - val_loss: 0.1317 - val_mean_absolute_error: 0.2337
# Epoch 21/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.1238 - mean_absolute_error: 0.2191 - val_loss: 0.1506 - val_mean_absolute_error: 0.2616
# Epoch 22/500
# 19/19 [==============================] - 1s 33ms/step - loss: 0.1172 - mean_absolute_error: 0.2008 - val_loss: 0.1740 - val_mean_absolute_error: 0.2896
# Epoch 23/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.1156 - mean_absolute_error: 0.1965 - val_loss: 0.1334 - val_mean_absolute_error: 0.2334
# Epoch 24/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.1129 - mean_absolute_error: 0.1963 - val_loss: 0.1571 - val_mean_absolute_error: 0.2664
# Epoch 25/500
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1141 - mean_absolute_error: 0.1946 - val_loss: 0.1561 - val_mean_absolute_error: 0.2683
# Epoch 26/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.1136 - mean_absolute_error: 0.1966 - val_loss: 0.1442 - val_mean_absolute_error: 0.2512
# Epoch 27/500
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1127 - mean_absolute_error: 0.1990 - val_loss: 0.1417 - val_mean_absolute_error: 0.2463
# Epoch 28/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.1127 - mean_absolute_error: 0.1988 - val_loss: 0.1441 - val_mean_absolute_error: 0.2490
# Epoch 29/500
# 19/19 [==============================] - 1s 33ms/step - loss: 0.1105 - mean_absolute_error: 0.1968 - val_loss: 0.1510 - val_mean_absolute_error: 0.2632
# Epoch 30/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.1121 - mean_absolute_error: 0.2017 - val_loss: 0.1377 - val_mean_absolute_error: 0.2342
# Epoch 31/500
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1117 - mean_absolute_error: 0.2043 - val_loss: 0.1447 - val_mean_absolute_error: 0.2544
# Epoch 32/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.1121 - mean_absolute_error: 0.2071 - val_loss: 0.1212 - val_mean_absolute_error: 0.2166
# Epoch 33/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.1100 - mean_absolute_error: 0.1987 - val_loss: 0.1305 - val_mean_absolute_error: 0.2364
# Epoch 34/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.1074 - mean_absolute_error: 0.1964 - val_loss: 0.1235 - val_mean_absolute_error: 0.2204
# Epoch 35/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.1044 - mean_absolute_error: 0.1958 - val_loss: 0.1312 - val_mean_absolute_error: 0.2290
# Epoch 36/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.1047 - mean_absolute_error: 0.1889 - val_loss: 0.1247 - val_mean_absolute_error: 0.2278
# Epoch 37/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.1029 - mean_absolute_error: 0.1958 - val_loss: 0.1337 - val_mean_absolute_error: 0.2373
# Epoch 38/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.1009 - mean_absolute_error: 0.1885 - val_loss: 0.1246 - val_mean_absolute_error: 0.2245
# Epoch 39/500
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0989 - mean_absolute_error: 0.1905 - val_loss: 0.1310 - val_mean_absolute_error: 0.2409
# Epoch 40/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0935 - mean_absolute_error: 0.1813 - val_loss: 0.1221 - val_mean_absolute_error: 0.2204
# Epoch 41/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.1015 - mean_absolute_error: 0.1965 - val_loss: 0.1251 - val_mean_absolute_error: 0.2230
# Epoch 42/500
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0916 - mean_absolute_error: 0.1872 - val_loss: 0.1328 - val_mean_absolute_error: 0.2486
# Epoch 43/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0880 - mean_absolute_error: 0.1771 - val_loss: 0.1467 - val_mean_absolute_error: 0.2507
# Epoch 44/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0920 - mean_absolute_error: 0.1910 - val_loss: 0.1188 - val_mean_absolute_error: 0.2212
# Epoch 45/500
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0856 - mean_absolute_error: 0.1771 - val_loss: 0.1294 - val_mean_absolute_error: 0.2364
# Epoch 46/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0862 - mean_absolute_error: 0.1803 - val_loss: 0.1232 - val_mean_absolute_error: 0.2250
# Epoch 47/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0823 - mean_absolute_error: 0.1698 - val_loss: 0.1260 - val_mean_absolute_error: 0.2338
# Epoch 48/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0820 - mean_absolute_error: 0.1773 - val_loss: 0.1295 - val_mean_absolute_error: 0.2404
# Epoch 49/500
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0828 - mean_absolute_error: 0.1751 - val_loss: 0.1360 - val_mean_absolute_error: 0.2527
# Epoch 50/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0777 - mean_absolute_error: 0.1684 - val_loss: 0.1227 - val_mean_absolute_error: 0.2284
# Epoch 51/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0768 - mean_absolute_error: 0.1621 - val_loss: 0.1278 - val_mean_absolute_error: 0.2332
# Epoch 52/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0778 - mean_absolute_error: 0.1724 - val_loss: 0.1243 - val_mean_absolute_error: 0.2322
# Epoch 53/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0770 - mean_absolute_error: 0.1683 - val_loss: 0.1343 - val_mean_absolute_error: 0.2402
# Epoch 54/500
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0777 - mean_absolute_error: 0.1653 - val_loss: 0.1283 - val_mean_absolute_error: 0.2323
# Epoch 55/500
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0764 - mean_absolute_error: 0.1683 - val_loss: 0.1142 - val_mean_absolute_error: 0.2124
# Epoch 56/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0764 - mean_absolute_error: 0.1658 - val_loss: 0.1447 - val_mean_absolute_error: 0.2545
# Epoch 57/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0819 - mean_absolute_error: 0.1769 - val_loss: 0.1417 - val_mean_absolute_error: 0.2519
# Epoch 58/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0882 - mean_absolute_error: 0.1909 - val_loss: 0.1517 - val_mean_absolute_error: 0.2641
# Epoch 59/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0815 - mean_absolute_error: 0.1771 - val_loss: 0.1268 - val_mean_absolute_error: 0.2361
# Epoch 60/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0782 - mean_absolute_error: 0.1657 - val_loss: 0.1367 - val_mean_absolute_error: 0.2407
# Epoch 61/500
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0734 - mean_absolute_error: 0.1652 - val_loss: 0.1389 - val_mean_absolute_error: 0.2508
# Epoch 62/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0754 - mean_absolute_error: 0.1664 - val_loss: 0.1428 - val_mean_absolute_error: 0.2561
# Epoch 63/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0704 - mean_absolute_error: 0.1590 - val_loss: 0.1351 - val_mean_absolute_error: 0.2491
# Epoch 64/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0726 - mean_absolute_error: 0.1593 - val_loss: 0.1411 - val_mean_absolute_error: 0.2521
# Epoch 65/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0715 - mean_absolute_error: 0.1584 - val_loss: 0.1531 - val_mean_absolute_error: 0.2647
# Epoch 66/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0784 - mean_absolute_error: 0.1759 - val_loss: 0.1263 - val_mean_absolute_error: 0.2329
# Epoch 67/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0717 - mean_absolute_error: 0.1593 - val_loss: 0.1454 - val_mean_absolute_error: 0.2581
# Epoch 68/500
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0689 - mean_absolute_error: 0.1555 - val_loss: 0.1267 - val_mean_absolute_error: 0.2318
# Epoch 69/500
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0714 - mean_absolute_error: 0.1602 - val_loss: 0.1286 - val_mean_absolute_error: 0.2372
# Epoch 70/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0694 - mean_absolute_error: 0.1598 - val_loss: 0.1358 - val_mean_absolute_error: 0.2455
# Epoch 71/500
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0666 - mean_absolute_error: 0.1492 - val_loss: 0.1283 - val_mean_absolute_error: 0.2327
# Epoch 72/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0666 - mean_absolute_error: 0.1542 - val_loss: 0.1329 - val_mean_absolute_error: 0.2406
# Epoch 73/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0678 - mean_absolute_error: 0.1537 - val_loss: 0.1339 - val_mean_absolute_error: 0.2425
# Epoch 74/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0658 - mean_absolute_error: 0.1498 - val_loss: 0.1381 - val_mean_absolute_error: 0.2478
# Epoch 75/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0678 - mean_absolute_error: 0.1569 - val_loss: 0.1365 - val_mean_absolute_error: 0.2508
# Epoch 76/500
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0677 - mean_absolute_error: 0.1562 - val_loss: 0.1400 - val_mean_absolute_error: 0.2520
# Epoch 77/500
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0678 - mean_absolute_error: 0.1532 - val_loss: 0.1442 - val_mean_absolute_error: 0.2568
# Epoch 78/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0675 - mean_absolute_error: 0.1567 - val_loss: 0.1589 - val_mean_absolute_error: 0.2692
# Epoch 79/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0681 - mean_absolute_error: 0.1568 - val_loss: 0.1318 - val_mean_absolute_error: 0.2404
# Epoch 80/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0634 - mean_absolute_error: 0.1471 - val_loss: 0.1321 - val_mean_absolute_error: 0.2425
# Epoch 81/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0617 - mean_absolute_error: 0.1458 - val_loss: 0.1288 - val_mean_absolute_error: 0.2342
# Epoch 82/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0626 - mean_absolute_error: 0.1461 - val_loss: 0.1347 - val_mean_absolute_error: 0.2406
# Epoch 83/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0619 - mean_absolute_error: 0.1441 - val_loss: 0.1372 - val_mean_absolute_error: 0.2476
# Epoch 84/500
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0618 - mean_absolute_error: 0.1474 - val_loss: 0.1479 - val_mean_absolute_error: 0.2616
# Epoch 85/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0597 - mean_absolute_error: 0.1398 - val_loss: 0.1299 - val_mean_absolute_error: 0.2367
# Epoch 86/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0595 - mean_absolute_error: 0.1393 - val_loss: 0.1370 - val_mean_absolute_error: 0.2469
# Epoch 87/500
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0607 - mean_absolute_error: 0.1442 - val_loss: 0.1353 - val_mean_absolute_error: 0.2472
# Epoch 88/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0609 - mean_absolute_error: 0.1434 - val_loss: 0.1381 - val_mean_absolute_error: 0.2496
# Epoch 89/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0593 - mean_absolute_error: 0.1420 - val_loss: 0.1311 - val_mean_absolute_error: 0.2392
# Epoch 90/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0584 - mean_absolute_error: 0.1402 - val_loss: 0.1513 - val_mean_absolute_error: 0.2585
# Epoch 91/500
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0586 - mean_absolute_error: 0.1402 - val_loss: 0.1344 - val_mean_absolute_error: 0.2433
# Epoch 92/500
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0588 - mean_absolute_error: 0.1418 - val_loss: 0.1397 - val_mean_absolute_error: 0.2483
# Epoch 93/500
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0640 - mean_absolute_error: 0.1538 - val_loss: 0.1318 - val_mean_absolute_error: 0.2400
# Epoch 94/500
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0592 - mean_absolute_error: 0.1418 - val_loss: 0.1340 - val_mean_absolute_error: 0.2390
# Epoch 95/500
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0567 - mean_absolute_error: 0.1359 - val_loss: 0.1371 - val_mean_absolute_error: 0.2425

# %%
plot_test(test_x[5], test_y[5], model=multi_lstm_model)
preds = multi_lstm_model(test_x)

m = tf.keras.metrics.MeanAbsolutePercentageError()
m.update_state(test_y, preds)
print('MAPE :',m.result().numpy(),'%')
# Out:
# MAPE : 54.847775 %

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_absolute_error

mape = mean_absolute_percentage_error(preds.numpy().reshape(37,5), test_y)
mse = mean_squared_error(preds.numpy().reshape(37,5), test_y)
mae = mean_absolute_error(preds.numpy().reshape(37,5), test_y)

print('MAPE :', round(mape *100,2) ,'%')
print('MSE :', round(mse,2))
print('MAE :', round(mae,2))
# Out:
# MAPE : 43.08 %
# MSE : 0.15
# MAE : 0.2

# %%
CONV_WIDTH = 3
multi_conv_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, CONV_WIDTH, features]
    tf.keras.layers.Lambda(lambda x: x[:, -CONV_WIDTH:, :]),
    # Shape => [batch, 1, conv_units]
    tf.keras.layers.Conv1D(256, activation='relu', kernel_size=(CONV_WIDTH)),
    # Shape => [batch, 1,  out_steps*features]
    tf.keras.layers.Dense(FORECAST_SIZE*NUM_FEATURES,
                          kernel_initializer=tf.initializers.zeros()),
    # Shape => [batch, out_steps, features]
    tf.keras.layers.Reshape([FORECAST_SIZE, NUM_FEATURES])
])

history = compile_and_fit(
    multi_conv_model,
    200,
    train_x,
    train_y,
    val_x,
    val_y)

# %%
plot_test(test_x[0], test_y[0], model=multi_conv_model)
preds = multi_conv_model(test_x)

m = tf.keras.metrics.MeanAbsolutePercentageError()
m.update_state(test_y, preds)
print('MAPE :',m.result().numpy(),'%')

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
